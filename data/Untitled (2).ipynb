# %%
import urllib
import urllib.request
import urllib.parse
from urllib.request import urlopen 
from urllib.request import urlretrieve 

from datetime import datetime
import time,locale

from bs4 import BeautifulSoup
import re
import unicodedata

import pandas as pd

# %%
from geopy.geocoders import Nominatim
import random,string

dfClub = pd.read_csv('Club.csv', sep=',')

def getGeoLoc(geolocator,address):
    random_str = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10));
    geolocator = Nominatim(user_agent=random_str)
    time.sleep(1.5)
    try:
        location = geolocator.geocode(address,timeout=10)
        if(location is not None):
            return (location.latitude, location.longitude)
        else:
            return None
    except (KeyboardInterrupt, SystemExit):
        raise
    except BaseException as e:
        print("Error: geocode failed on input %s with message %s"%(address, str(e)))
        return None
    
dfClub['coords'] = dfClub['city_name'].map(lambda x: getGeoLoc(geolocator,x))
dfClub
# Out:
#         id                                            name  short_name  \
# 0        0                               Zem'bad Le Montat      ZEMBAD
# 1        1                           Yvetot Badminton Club         YBC
# 2        2                                 Xtrem Bad Poisy       XBP74
# 3        3                                       Wolfi'Bad   WOLFI.BAD
# 4        4                        Wasquehal Badminton Club         WBC
# 5        5                        Woincourt Badminton Club         WBC
# 6        6                                 Who's Bad Paris          WB
# 7        7                 Who's Bad - Le Badminton Galant          WB
# 8        8                             Volants Wormhoutois          VW
# 9        9             Les Volants de la Vallée de Munster         VVM
# 10      10                           Les Volants Du Vuache        VV74
# 11      11                                 Volants Vençois        VV06
# 12      12                    VALENCIENNES UNIVERSITÉ CLUB         VUC
# 13      13      Les Volants Tranchais Omnisports Badminton         VTO
# 14      14                           Vga Stella Saint Maur        VSSM
# 15      15                             Volant Saint Martin         VSM
# 16      16                              Velo Sport Fertois         VSF
# 17      17                     Volant Stéphanois Badminton         VSB
# 18      18                         Val De Sarthe Badminton         VSB
# 19      19                    Villemomble Sports Badminton         VSB
# 20      20               Vaillante Sports Angers Badminton      VSABAD
# 21      21                              Volant Savenaisien          VS
# 22      22                           Le Volant Sammiellois          VS
# 23      23                        Les Volants de Sermaises          VS
# 24      24                                 Volant Cécilien          VS
# 25      25                     Volant Radieux Pinsaguelois         VRP
# 26      26                                Volant Quingeois          VQ
# 27      27                          Le Volant d'Oc Vauréen         VOV
# 28      28                Vaillante Omnisport  Saint Brice        VOSB
# 29      29                               Volant Opale Club         VOC
# ...    ...                                             ...         ...
# 2173  2173           Association de Badminton de Chabanais         ABC
# 2174  2174                        Andrésien Badminton Club         ABC
# 2175  2175                            Ardon Badminton Club         ABC
# 2176  2176                          Allaire Badminton Club         ABC
# 2177  2177              Andrezieux Bouthéon Badminton Club      ABBC42
# 2178  2178                          Anet Bu Badminton Club        ABBC
# 2179  2179                          Anille Braye Badminton       ABBAB
# 2180  2180                Ass. Badminton Bourgogne Avallon        ABBA
# 2181  2181                 Association Badminton Beconnais         ABB
# 2182  2182                      Association Boos Badminton         ABB
# 2183  2183                Association de Badminton de Foix        ABAF
# 2184  2184                                       Auber'Bad        ABAD
# 2185  2185          Association de  Badminton de Châtillon        ABAC
# 2186  2186                              Ancemont Badminton         ABA
# 2187  2187              Association de Badminton d'Amanlis         ABA
# 2188  2188                               Ambazac Badminton        AB87
# 2189  2189            Association Badminton des 3 Rivières      AB3R01
# 2190  2190  Association Badminton Club de Chouzy sur Cisse        AB3C
# 2191  2191                             AVANTi Badminton 13        AB13
# 2192  2192                             AJEVIF Badminton 13        AB13
# 2193  2193                                        Arcy Bad          AB
# 2194  2194           Ass. Amic. Sport. Sarcelles badminton     AASSB95
# 2195  2195                     Ass. Amicale Sport. Fresnes        AASF
# 2196  2196               As. A. et S. De Clery Saint Andre        AASC
# 2197  2197                        Avenir Amboise Badminton         AAB
# 2198  2198   Association de Badminton de Corcoué sur Logne  A.B.C.L.44
# 2199  2199                            Auros Badminton Club       A.B.C
# 2200  2200                                 4ème Set Rognen         4SR
# 2201  2201                S. Sport. De La Securite Sociale          4S
# 2202  2202               Fédération Française de Badminton         NaN
#
#                      city_name  lat  long  url  \
# 0                    Le Montat  NaN   NaN  NaN
# 1                       Yvetot  NaN   NaN  NaN
# 2                        Poisy  NaN   NaN  NaN
# 3                   Wolfisheim  NaN   NaN  NaN
# 4                    Wasquehal  NaN   NaN  NaN
# 5                    Woincourt  NaN   NaN  NaN
# 6                        Paris  NaN   NaN  NaN
# 7                  Grand-Bourg  NaN   NaN  NaN
# 8                     Wormhout  NaN   NaN  NaN
# 9                      Munster  NaN   NaN  NaN
# 10                     Vulbens  NaN   NaN  NaN
# 11                       Vence  NaN   NaN  NaN
# 12                Valenciennes  NaN   NaN  NaN
# 13          La Tranche-sur-Mer  NaN   NaN  NaN
# 14       Saint-Maur-des-Fossés  NaN   NaN  NaN
# 15                    Toulouse  NaN   NaN  NaN
# 16            La Ferté-Bernard  NaN   NaN  NaN
# 17    Saint-Etienne-de-Tulmont  NaN   NaN  NaN
# 18            Noyen-sur-Sarthe  NaN   NaN  NaN
# 19                 Villemomble  NaN   NaN  NaN
# 20                      Angers  NaN   NaN  NaN
# 21                     Savenay  NaN   NaN  NaN
# 22                Saint-Mihiel  NaN   NaN  NaN
# 23                   Sermaises  NaN   NaN  NaN
# 24    Sainte-Cécile-les-Vignes  NaN   NaN  NaN
# 25                   Pinsaguel  NaN   NaN  NaN
# 26                     Quingey  NaN   NaN  NaN
# 27                      Lavaur  NaN   NaN  NaN
# 28      Saint-Brice-sous-Forêt  NaN   NaN  NaN
# 29            Boulogne-sur-Mer  NaN   NaN  NaN
# ...                        ...  ...   ...  ...
# 2173                 Chabanais  NaN   NaN  NaN
# 2174                   Coudres  NaN   NaN  NaN
# 2175                     Ardon  NaN   NaN  NaN
# 2176                   Allaire  NaN   NaN  NaN
# 2177       Andrézieux-Bouthéon  NaN   NaN  NaN
# 2178                      Anet  NaN   NaN  NaN
# 2179              Saint-Calais  NaN   NaN  NaN
# 2180                   Avallon  NaN   NaN  NaN
# 2181         Bécon-les-Granits  NaN   NaN  NaN
# 2182                      Boos  NaN   NaN  NaN
# 2183                      Foix  NaN   NaN  NaN
# 2184             Aubervilliers  NaN   NaN  NaN
# 2185                 Châtillon  NaN   NaN  NaN
# 2186                  Ancemont  NaN   NaN  NaN
# 2187                   Amanlis  NaN   NaN  NaN
# 2188                   Ambazac  NaN   NaN  NaN
# 2189       Montmerle-sur-Saône  NaN   NaN  NaN
# 2190          Chouzy-sur-Cisse  NaN   NaN  NaN
# 2191                     Paris  NaN   NaN  NaN
# 2192                     Paris  NaN   NaN  NaN
# 2193               Bois-d'Arcy  NaN   NaN  NaN
# 2194                 Sarcelles  NaN   NaN  NaN
# 2195                   Fresnes  NaN   NaN  NaN
# 2196         Cléry-Saint-André  NaN   NaN  NaN
# 2197                   Amboise  NaN   NaN  NaN
# 2198         Corcoué-sur-Logne  NaN   NaN  NaN
# 2199                     Auros  NaN   NaN  NaN
# 2200                    Rognes  NaN   NaN  NaN
# 2201                    Rennes  NaN   NaN  NaN
# 2202                Saint-Ouen  NaN   NaN  NaN
#
#                                 coords
# 0              (44.3797732, 1.4458932)
# 1              (49.6179384, 0.7538866)
# 2              (45.9220363, 6.0626528)
# 3              (48.5875517, 7.6672188)
# 4              (50.6691577, 3.1312447)
# 5              (50.0649737, 1.5372026)
# 6              (48.8566101, 2.3514992)
# 7              (46.1600762, 1.6459099)
# 8               (50.8827628, 2.468733)
# 9      (52.3076216, -8.57089727629267)
# 10             (46.1011166, 5.9311875)
# 11             (43.7226204, 7.1118067)
# 12             (50.3594889, 3.5266657)
# 13            (46.3440097, -1.4380541)
# 14             (48.8033057, 2.4853015)
# 15             (43.6044622, 1.4442469)
# 16             (48.1851241, 0.6550005)
# 17             (44.0488889, 1.4627778)
# 18            (47.8723118, -0.0992579)
# 19              (48.881886, 2.5076181)
# 20            (47.4739884, -0.5515588)
# 21            (47.3592304, -1.9421244)
# 22              (48.891207, 5.5423046)
# 23             (48.2969333, 2.2039781)
# 24             (44.2464525, 4.8868861)
# 25             (43.5099932, 1.3884681)
# 26             (47.1038613, 5.8831349)
# 27              (43.6989332, 1.815187)
# 28             (48.9973824, 2.3568948)
# 29             (50.7259985, 1.6118771)
# ...                                ...
# 2173           (45.8735576, 0.7188033)
# 2174           (48.8644335, 1.2470672)
# 2175          (42.4364485, -5.5605337)
# 2176          (47.6373804, -2.1625362)
# 2177    (45.5351545, 4.27990164825709)
# 2178           (48.8527002, 1.4430466)
# 2179           (47.9201366, 0.7434396)
# 2180           (47.4885365, 3.9070658)
# 2181          (47.5034433, -0.8012205)
# 2182  (43.8943854, -0.988833740023658)
# 2183           (42.9638998, 1.6053807)
# 2184           (48.9146078, 2.3821895)
# 2185           (48.7997756, 2.2897124)
# 2186           (49.0704023, 5.4078747)
# 2187          (48.0061864, -1.4764193)
# 2188            (45.958226, 1.4019278)
# 2189           (46.0840019, 4.7614129)
# 2190    (47.5245948, 1.23475430997112)
# 2191           (48.8566101, 2.3514992)
# 2192           (48.8566101, 2.3514992)
# 2193             (48.799856, 2.023607)
# 2194           (48.9960813, 2.3796245)
# 2195           (49.5544444, 3.3705556)
# 2196           (47.8212402, 1.7569328)
# 2197            (47.4110351, 0.983698)
# 2198           (46.965977, -1.5772672)
# 2199              (44.49491, -0.14635)
# 2200           (43.6638292, 5.3469001)
# 2201          (48.1113387, -1.6800198)
# 2202             (48.911729, 2.334267)
#
# [2203 rows x 8 columns]

# %%
#dfClub['coords'].apply(lambda x: print(x[0]))
dfClub['lat'] = dfClub['coords'].map(lambda x: x[0] if x is not None else None)
dfClub['long'] = dfClub['coords'].map(lambda x: x[1] if x is not None else None)
dfClub.to_csv('Club_geo.csv', columns = ['name','short_name','city_name','lat','long','url'])

# %% [markdown]
# ### Create empty dataframes for all classes

# %%
tournament_fields = ['name', 'club_id','start_date','url','lat', 'long','price_1_tab','price_2_tabs','price_3_tabs']
dfTourn = pd.DataFrame(columns = tournament_fields)
dfTourn.index.names = ['id']

tournament_ranking_fields = ['name']
dfTournament_ranking = pd.DataFrame(columns = tournament_ranking_fields)
dfTournament_ranking.index.names = ['id']


tournament_category_fields = ['name']
dfTournament_category = pd.DataFrame(columns = tournament_category_fields)
dfTournament_category.index.names = ['id']


player_fields = ['license','name','surname','gender']
dfPlayer = pd.DataFrame(columns = player_fields)


accepts_ranking_fields = ['tid','trid']
dfAccepts_ranking = pd.DataFrame(columns = accepts_ranking_fields)


accepts_category_fields = ['tid','tcid']
dfAccepts_category = pd.DataFrame(columns = accepts_category_fields)


participates_fields = ['pid','tid']
dfParticipates = pd.DataFrame(columns = participates_fields)

# %% [markdown]
# ### create table tournament_ranking

# %%
dfTournament_ranking.loc[0] = ['N1']
dfTournament_ranking.loc[1] = ['N2']
dfTournament_ranking.loc[2] = ['N3']
dfTournament_ranking.loc[3] = ['R4']
dfTournament_ranking.loc[4] = ['R5']
dfTournament_ranking.loc[5] = ['R6']
dfTournament_ranking.loc[6] = ['D7']
dfTournament_ranking.loc[7] = ['D8']
dfTournament_ranking.loc[8] = ['D9']
dfTournament_ranking.loc[9] = ['P10']
dfTournament_ranking.loc[10] = ['P11']
dfTournament_ranking.loc[11] = ['P12']
dfTournament_ranking.loc[12] = ['NC']
dfTournament_ranking.loc[13] = ['undefined']

dfTournament_ranking.to_csv('TournamentRanking.csv')

# %% [markdown]
# ### method that, given a list of rankings, finds the corresponding ids and adds the pairs to table accepts_ranking

# %%
def addRanking(rk, tid):
    switcher = {
        'D' : [6, 7, 8],
        'D+' : [6, 7],
        'D-' : [7, 8],
        'D7' : [6],
        'D8' : [7],
        'D9' : [8],
        'N' : [0, 1, 2],
        'N+' : [0, 1 ],
        'N-' : [1, 2],
        'N1' : [0],
        'N2' : [1],
        'N3' : [2],
        'NC' : [12],
        'P' : [9, 10, 11],
        'P+' : [9, 10],
        'P-' : [10, 11],
        'P10' : [9],
        'P11' : [10],
        'P12' : [11],
        'R' : [3, 4, 5],
        'R+' : [3, 4],
        'R-' : [4, 5],
        'R4' : [3],
        'R5' : [4],
        'R6 ' : [5]
    }
    for r in rk:
        gets = switcher.get(r, [13])
        for g in gets: 
            dfAccepts_ranking.loc[len(dfAccepts_ranking)] = [tid, g]

# %% [markdown]
# ### create table tournament_category

# %%
dfTournament_category.loc[0] = ['Veteran']
dfTournament_category.loc[1] = ['Senior']
dfTournament_category.loc[2] = ['Jeune']
dfTournament_category.loc[3] = ['Undefined']

dfTournament_category.to_csv('TournamentCategory.csv')

# %% [markdown]
# ### method that, given a list of categories, finds the corresponding id and adds the pairs to table accepts_category

# %%
def addCategory(cat, tid):
    switcher = {
        'Veteran' : 0,
        'Vétéran' : 0,
        'Vet' : 0,
        'Vét' : 0,
        'Senior' : 1,
        'Jeune' : 2
    }
    for r in cat:
        get = switcher.get(r, [3])
        dfAccepts_category.loc[len(dfAccepts_category)] = [tid, get]

# %% [markdown]
# ### fetch page

# %%
pages = []

for i in range(8):
    url = 'http://badiste.fr/liste-tournoi-badminton?c2=0&u2=1&page2=' + str(i + 1) + '#table2'
    data = urllib.parse.urlencode({'date' : '100'}).encode("utf-8")

    req = urllib.request.Request(url)
    with urllib.request.urlopen(req,data=data) as f:
        resp = f.read()

    #codeSource = html.read().decode('utf-8')
    soup = BeautifulSoup(resp, 'html.parser')
    pages.append(soup)

# %% [markdown]
# ### Store clubs in dataframe

# %%
dfClub = pd.read_csv('badiste_Club.csv', encoding = 'iso-8859-15', sep=';')
dfClub.drop(columns = dfClub.columns[range(4,17)], inplace=True)
dfClub.columns = ['name','short_name','dep','city_name']
dfClub.drop(columns='dep', inplace=True)
dfClub.index.names = ['id']

dfClub["name_search"] = dfClub["name"] + " (" + dfClub["short_name"] + ")"
dfClub.to_csv('Club.csv', columns = ['name','short_name','city_name','lat','long','url'])
def getClubId(search_str, df):
    return df.index[df['name_search'] == search_str].tolist()
# Out:
# C:\Users\LMG\Anaconda3\lib\site-packages\pandas\io\formats\format.py:1586: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   self.obj = self.obj.loc[:, cols]
# C:\Users\LMG\Anaconda3\lib\site-packages\pandas\core\indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# ### Fetch all tournaments of one page

# %%
pageNb = 1
for p in pages:
    print("scraping page number ", pageNb)
    pageNb = pageNb + 1
    trs = p.find_all("tr", {"class": ["tux", "tux1"]})
    for i in range(len(trs)):
        
        if ((i * 100 / len(trs))%10 == 0):
            print("percentage: ", (i * 100 / len(trs)))
        
        tourn = trs[i] #TODO: change 15 into i
        tds = tourn.find_all('td')

        names = tds[1].find_all('a')[1]
        link = names['href']
        name = names.text.replace('17-18', '')

        cat = tds[7].text
        cats = re.split(' et |,|',cat)
        addCategory(cats, i)

        classmt = tds[8].text
        clas = re.split(',|;|/|-',classmt)   
        addRanking(clas, i)

        html = urlopen("http://badiste.fr/" + link)
        codeSource = html.read().decode('iso-8859-15')
        tsoup = BeautifulSoup(codeSource, 'html.parser')

        infos = tsoup.find_all("td", {"class":  "forminfo"})

        clubName = infos[0].text
        clubId = getClubId(clubName, dfClub)

        realDate = infos[1].text
        locale.setlocale(locale.LC_TIME, "French_France.1252") 
        datetime_object = datetime.strptime(realDate, '%A %d %B %Y')
        date = datetime_object.strftime("%d.%m.%Y")

        cost = infos[8].text
        c = re.search('[^0-9]*(\d*)[^0-9]*(\d*)[^0-9]*(\d*).*', str(cost))

        try:
            onetb = c.group(1)
        except IndexError:
            onetb = ""

        try:
            twotb = c.group(2)
        except IndexError:
            twotb = ""
        try:
            threetb = c.group(3)
        except IndexError:
            threetb = ""

        geo = infos[9]
        m = re.search('GPS : (-?\d*.\d*), (-?\d*.\d*)', str(geo))
        if m:
            lat = m.group(1)
            long = m.group(2)

        dfTourn.loc[len(dfTourn)] = [name, clubId[0] if len(clubId) > 0 else -1,  date, link, lat, long, onetb, twotb, threetb]

        time.sleep(0.5)
# Out:
# scraping page number  1
# percentage:  0.0
# C:\Users\LMG\Anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  2
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  3
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  4
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  5
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  6
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  7
# percentage:  0.0
# percentage:  10.0
# percentage:  20.0
# percentage:  30.0
# percentage:  40.0
# percentage:  50.0
# percentage:  60.0
# percentage:  70.0
# percentage:  80.0
# percentage:  90.0
# scraping page number  8
# percentage:  0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512         try:
# --> 513             return int(line, 16)
#     514         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~\Anaconda3\lib\http\client.py in _readall_chunked(self)
#     562             while True:
# --> 563                 chunk_left = self._get_chunk_left()
#     564                 if chunk_left is None:
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     547             except ValueError:
# --> 548                 raise IncompleteRead(b'')
#     549             if chunk_left == 0:
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-12-3eee882ce521> in <module>()
#      25
#      26         html = urlopen("http://badiste.fr/" + link)
# ---> 27         codeSource = html.read().decode('iso-8859-15')
#      28         tsoup = BeautifulSoup(codeSource, 'html.parser')
#      29
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     454
#     455             if self.chunked:
# --> 456                 return self._readall_chunked()
#     457
#     458             if self.length is None:
#
# ~\Anaconda3\lib\http\client.py in _readall_chunked(self)
#     568             return b''.join(value)
#     569         except IncompleteRead:
# --> 570             raise IncompleteRead(b''.join(value))
#     571
#     572     def _readinto_chunked(self, b):
#
# IncompleteRead: IncompleteRead(28726 bytes read)

# %%
dfTourn.to_csv('Tournament.csv')

dfAccepts_ranking.to_csv('accepts_ranking.csv', index = False)

dfAccepts_category.to_csv('accepts_category.csv', index = False)

#dfParticipates = pd.DataFrame(columns = participates_fields)
#not done participate yet

# %% [markdown]
# ### fetch all players for each club and store them in df

# %%
c = 0
wrongClubs = []
for c in range(len(dfClub) - 1): #to remove the fédération
#for c in range(3):
    print("Club n° "+ str(c) +"/" + str(len(dfClub)))
    clubFullName = dfClub.at[c, 'name']
    sigle = dfClub.at[c, 'short_name']
    lowName = unicodedata.normalize('NFD', sigle).encode('ascii', 'ignore').decode('utf-8').lower()
    if(not ('comite' in lowName or 'ligue' in lowName)):
        c = c + 1
        try: 
            playersLink = 'http://badiste.fr/rechercher-joueur-badminton?todo=search&nom=&prenom=&licence=&genre=0&classement=0&categorie=0&ligue=-1&ville=&sigle='+ sigle +'&lim=1000&Submit=Rechercher'

            dataClub = urllib.parse.urlencode({'date' : '100'}).encode("utf-8")

            reqClub = urllib.request.Request(playersLink)
            with urllib.request.urlopen(reqClub,data=dataClub) as f:
                respClub = f.read()

            #codeSource = html.read().decode('utf-8')
            soupClub = BeautifulSoup(respClub, 'html.parser')
            genders = {'H': 0, 'F': 1}
            trsClub = soupClub.find_all("tr", {"class": "tux"})
            pl = 0
            player_count = 0
            for player in trsClub:
                
                if ((player_count * 100 / len(trsClub))%10 == 0):
                    print("\tplayers: " + (player_count * 100 / len(trsClub)) + "%")
                player_count+=1
                
                tdsClub = player.find_all('td')

                nameClub = re.search('(.[^A-Z]+)+([A-Z ]+)', tdsClub[0].text)
                playerName = nameClub.group(1).strip()
                playerSurname = nameClub.group(2).strip()

                if(not 'anonyme' in playerName.lower()):
                    playerLicense = tdsClub[10].text

                    playerGender = genders[tdsClub[1].text]

                    dfPlayer.loc[pl] = [playerLicense, playerName, playerSurname, playerGender]
                pl = pl + 1
        except:
            wrongClubs.append(sigle)
        time.sleep(0.5)
dfPlayer.to_csv('Player.csv', index=False)
wrongDf = pd.DataFrame({'col':wrongClubs})
wrongDf.to_csv('wrong_club_names.csv', index=False)
# Out:
# Club n° 0/2203
# Club n° 1/2203
# Club n° 2/2203
# Club n° 3/2203
# Club n° 4/2203
# Club n° 5/2203
# Club n° 6/2203
# Club n° 7/2203
# Club n° 8/2203
# Club n° 9/2203
# Club n° 10/2203
# Club n° 11/2203
# Club n° 12/2203
# Club n° 13/2203
# Club n° 14/2203
# Club n° 15/2203
# Club n° 16/2203
# Club n° 17/2203
# Club n° 18/2203
# Club n° 19/2203
# Club n° 20/2203
# Club n° 21/2203
# Club n° 22/2203
# Club n° 23/2203
# Club n° 24/2203
# Club n° 25/2203
# Club n° 26/2203
# Club n° 27/2203
# Club n° 28/2203
# Club n° 29/2203
# Club n° 30/2203
